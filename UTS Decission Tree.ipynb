# %% [markdown]
# ## RAFIDAH SHAFA ARIZA RAMADHAN
# ## 202131139
# ## UTS PEMBELAJARAN MESIN

# %% [markdown]
# ## IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# yang pertama kita harus meng import Library
# pandas untuk memproses membaca data
# Numpy untuk membaca angka
# Matplotlibpyplot untuk memvisualisasi data

# %% [markdown]
# ## IMPORT DATA

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Selanjutnya kita meng import data. Di sini saya menggunakan data set diabetes.csv

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# data.info di gunakan untuk mengetahui info yang ada dalam data set yang sudah di import yaitu dataset diabetes.csv

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Describe() adalah fungsi yang dapat digunakan untuk melihat deskripsi statistika dari data. Secara default hanya menampilkan data yang bertipe data numerik. Data numerik memiliki deskripsi statistik seperti mean, median, standar deviasi, dan quartil

# %% [markdown]
# ## MENGUBAH OBJEK MENJADI NUMERIK

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction','Age','Outcome']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    data
    print (data['Pregnancies'],data['Glucose'],data['BloodPressure'],data['SkinThickness'],data['Insulin'],data['BMI'],data['DiabetesPedigreeFunction'],data['Age'],data['Outcome'])
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# ...

# %% [markdown]
# Mengubah objek menjadi data numerik karena hanya bisa dijalankan apabila data menjadi numerik

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6       86             22             28        0  123
# 1              1       23             19             22        0   62
# 2              8      121             17              0        0   30
# 3              1       27             19             16       62   77
# 4              0       75              4             28      102  209
# ..           ...      ...            ...            ...      ...  ...
# 763           10       39             25             41      108  118
# 764            2       60             21             20        0  155
# 765            5       59             22             16       71   58
# 766            1       64             14              0        0   95
# 767            1       31             21             24        0   98
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                         350   29        1
# ...

# %% [markdown]
# Menampilkan data baru setelah di ubah

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    int64
#  6   DiabetesPedigreeFunction  768 non-null    int64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: int64(9)
# memory usage: 54.1 KB

# %% [markdown]
# Mempilkan info pada data set diabetes.csv

# %%
data=data.drop('Pregnancies',axis=1)print (x_train)

# %% [markdown]
# ## PEMODELAN
# Decision Tree

# %%
x = data.drop('Outcome', axis = 1)
y = data['Outcome']

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0         86             22             28        0  123
# 1         23             19             22        0   62
# 2        121             17              0        0   30
# 3         27             19             16       62   77
# 4         75              4             28      102  209
# ..       ...            ...            ...      ...  ...
# 763       39             25             41      108  118
# 764       60             21             20        0  155
# 765       59             22             16       71   58
# 766       64             14              0        0   95
# 767       31             21             24        0   98
#
#      DiabetesPedigreeFunction  Age
# 0                         350   29
# 1                         196   10
# 2                         368   11
# 3                          53    0
# 4                         514   12
# ..                        ...  ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state =0)

# %%
print (x_train)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 580       89             33             39        0  201
# 418       21             20              0        0    1
# 764       60             21             20        0  155
# 363       84             26              0        0  172
# 757       61             22              0        0  150
# ..       ...            ...            ...      ...  ...
# 763       39             25             41      108  118
# 192       97             19              0        0   98
# 629       32             18             15        0   44
# 559       23             23              0        0   95
# 684       74             28              0        0    0
#
#      DiabetesPedigreeFunction  Age
# 580                       208    0
# 418                       348    6
# 764                       187    6
# 363                       297   46
# 757                       127   31
# ..                        ...  ...
# ...

# %%
print (y_train)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 580       89             33             39        0  201
# 418       21             20              0        0    1
# 764       60             21             20        0  155
# 363       84             26              0        0  172
# 757       61             22              0        0  150
# ..       ...            ...            ...      ...  ...
# 763       39             25             41      108  118
# 192       97             19              0        0   98
# 629       32             18             15        0   44
# 559       23             23              0        0   95
# 684       74             28              0        0    0
#
#      DiabetesPedigreeFunction  Age
# 580                       208    0
# 418                       348    6
# 764                       187    6
# 363                       297   46
# 757                       127   31
# ..                        ...  ...
# ...

# %%
print (x_test)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 661      135             25             36        0  208
# 122       45             23             23       66  123
# 113       14             16              0        0  127
# 14       104             22             12      105   54
# 529       49             18              0        0   43
# ..       ...            ...            ...      ...  ...
# 165       42             23             11       95   93
# 188       47             25             32       72   75
# 334       33             14             11       30   36
# 758       44             25              0        0  162
# 34        60             26             24        0   72
#
#      DiabetesPedigreeFunction  Age
# 661                       502    1
# 122                       231    2
# 113                       220    4
# 14                        331   30
# 529                       364   10
# ..                        ...  ...
# ...

# %%
print (y_test)
# Out:
# 661    1
# 122    0
# 113    0
# 14     1
# 529    0
#       ..
# 165    1
# 188    1
# 334    0
# 758    0
# 34     0
# Name: Outcome, Length: 231, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier(max_depth=2)
model_DT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# Melakukan pelatihan model dengan algoritma Decission Tree Classifier

# %%
predict_DT = model_DT.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("akurasi score sebenarnya: ", accuracy_score(y_test, predict_DT)*100)
# Out:
# akurasi score sebenarnya:  72.72727272727273

# %% [markdown]
# Mengecek akurasi Model apabila nilai diatas 70 maka akurasi baik apabila akurasi di bawah 70 maka akurasi kurang baik

# %% [markdown]
# ## VISUALISASI DATA MODEL DECISION TREE

# %%
from sklearn.tree import plot_tree

plt.subplots(figsize=(12,10))
plot_tree (model_DT, fontsize = 10 )
plt.show()

# %% [markdown]
# Menampilkan bentuk visualisasi pohon yang dihasilkan dari model
